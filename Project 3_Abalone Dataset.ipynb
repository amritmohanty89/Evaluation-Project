# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import MultinomialNB,GaussianNB
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('abalone.data')
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %% [markdown]
# #### Lets check the null values without using visualization

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
#Check the Null value through graph
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(data.isnull())
plt.show()

# %%
data = pd.DataFrame(data=data)
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
data.shape
# Out:
# (4177, 9)

# %%
data.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
#For the column who has 3 attributes
from sklearn import preprocessing
for col in data.columns:
    if(len(data[col].value_counts()) ==3):#Unique values
        le_anima = preprocessing.LabelEncoder()
        data[col] = le_anima.fit_transform(data[col])

# %%
data
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
dfcor = data.corr()
dfcor
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# Diameter              0.893162        0.899724      0.905330  0.574660
# Height                0.774972        0.798319      0.817338  0.557467
# Whole weight          0.969405        0.966375      0.955355  0.540390
# Shucked weight        1.000000        0.931961      0.882617  0.420884
# Viscera weight        0.931961        1.000000      0.907656  0.503819
# Shell weight          0.882617        0.907656      1.000000  0.627574
# Rings                 0.420884        0.503819      0.627574  1.000000

# %%
sns.heatmap(dfcor)

# %%
plt.figure(figsize=(6,4))
sns.heatmap(dfcor,cmap='Blues',annot=False)

# %%
plt.figure(figsize=(6,4))
sns.heatmap(dfcor,cmap='Blues',annot=True)

# %% [markdown]
# #### There is a Low Correlation Between Sex and Other Columns So we are Deleting this Column

# %%
data.drop(['Sex'],axis=1,inplace=True)

# %%
data
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight  Rings
# 0           0.1500     15
# 1           0.0700      7
# 2           0.2100      9
# 3           0.1550     10
# 4           0.0550      7
# ...            ...    ...
# 4172        0.2490     11
# 4173        0.2605     10
# 4174        0.3080      9
# 4175        0.2960     10
# 4176        0.4950     12
#
# [4177 rows x 8 columns]

# %% [markdown]
# #### Removing the Outliers

# %%
#Lets check for outliers
from scipy.stats import zscore
z_score=abs(zscore(data))
print(data.shape)
data_final=data.loc[(z_score<3).all(axis=1)]
print(data_final.shape)
# Out:
# (4177, 8)
# (4027, 8)

# %% [markdown]
# #### Checking Skewness and Removing it

# %%
#Check Skewness 
data.skew()
#there is some skewness which need to be treated,by seeing we can say only +ve skewness is significant and needs to be treated
#if value is 0.55 or more than that then there would be a skewed value
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
#Treating the skewness using log
import numpy as np
for col in data.columns:
#Here complete column name has been passed
    if data.skew().loc[col]>0.55:
        data[col]=np.log1p(data[col])

# %%
#Lets Again Check the Skewness
data.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            1.099602
# Whole weight      0.530959
# Shucked weight    0.306439
# Viscera weight    0.375637
# Shell weight      0.315321
# Rings            -0.061317
# dtype: float64

# %%
#Lets Check the pairplot using seaborn Library
import seaborn as sns
sns.pairplot(data)
plt.show()

# %% [markdown]
# ### Plotting Boxplot through Iteration

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,15))
for i,col in enumerate(list(data.columns.values)):
    plt.subplot(5,5,i+1)
    data.boxplot(col)
    plt.grid()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Plotting Displot Through Iteration

# %%
plt.figure(figsize=(20,16))
for i,col in enumerate(list(data.columns.values)):
    plt.subplot(5,5,i+1)
    sns.distplot(data[col],color='r',kde=True,label='data')
    plt.grid()
    plt.legend(loc='upper right')
    plt.tight_layout()

# %%
data.columns
# Out:
# Index(['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# ### Plotting Data using scatter plot

# %%
plt.scatter(data['Length'],data['Rings'])

# %%
plt.scatter(data['Diameter'],data['Rings'])

# %%
plt.scatter(data['Height'],data['Rings'])

# %%
plt.scatter(data['Whole weight'],data['Rings'])

# %%
plt.scatter(data['Shucked weight'],data['Rings'])

# %%
plt.scatter(data['Viscera weight'],data['Rings'])

# %%
plt.scatter(data['Shell weight'],data['Rings'])

# %% [markdown]
# ### Column Plot

# %%
collist = data.columns.values
ncols=12
nrows=10

# %%
plt.figure(figsize=(ncols,5*ncols))
for i in range(1,len(collist)):
    plt.subplot(nrows,ncols,i+1)
    sns.boxplot(data[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# #### Separating X and Y Variable

# %%
data
# Out:
#       Length  Diameter    Height  Whole weight  Shucked weight  \
# 0      0.455     0.365  0.090754        0.5140        0.202533
# 1      0.350     0.265  0.086178        0.2255        0.094856
# 2      0.530     0.420  0.126633        0.6770        0.228330
# 3      0.440     0.365  0.117783        0.5160        0.195156
# 4      0.330     0.255  0.076961        0.2050        0.085719
# ...      ...       ...       ...           ...             ...
# 4172   0.565     0.450  0.152721        0.8870        0.314811
# 4173   0.590     0.440  0.126633        0.9660        0.363948
# 4174   0.600     0.475  0.186480        1.1760        0.422322
# 4175   0.625     0.485  0.139762        1.0945        0.425921
# 4176   0.710     0.555  0.178146        1.9485        0.665519
#
#       Viscera weight  Shell weight     Rings
# 0           0.096219      0.139762  2.772589
# 1           0.047361      0.067659  2.079442
# 2           0.132343      0.190620  2.302585
# 3           0.107957      0.144100  2.397895
# 4           0.038740      0.053541  2.079442
# ...              ...           ...       ...
# 4172        0.214305      0.222343  2.484907
# 4173        0.194332      0.231508  2.397895
# 4174        0.252702      0.268499  2.302585
# 4175        0.231905      0.259283  2.397895
# 4176        0.319544      0.402126  2.564949
#
# [4177 rows x 8 columns]

# %%
X = data.drop("Rings", axis=1)

# %%
X
# Out:
#       Length  Diameter    Height  Whole weight  Shucked weight  \
# 0      0.455     0.365  0.090754        0.5140        0.202533
# 1      0.350     0.265  0.086178        0.2255        0.094856
# 2      0.530     0.420  0.126633        0.6770        0.228330
# 3      0.440     0.365  0.117783        0.5160        0.195156
# 4      0.330     0.255  0.076961        0.2050        0.085719
# ...      ...       ...       ...           ...             ...
# 4172   0.565     0.450  0.152721        0.8870        0.314811
# 4173   0.590     0.440  0.126633        0.9660        0.363948
# 4174   0.600     0.475  0.186480        1.1760        0.422322
# 4175   0.625     0.485  0.139762        1.0945        0.425921
# 4176   0.710     0.555  0.178146        1.9485        0.665519
#
#       Viscera weight  Shell weight
# 0           0.096219      0.139762
# 1           0.047361      0.067659
# 2           0.132343      0.190620
# 3           0.107957      0.144100
# 4           0.038740      0.053541
# ...              ...           ...
# 4172        0.214305      0.222343
# 4173        0.194332      0.231508
# 4174        0.252702      0.268499
# 4175        0.231905      0.259283
# 4176        0.319544      0.402126
#
# [4177 rows x 7 columns]

# %%
Y = data["Rings"]
Y
# Out:
# 0       2.772589
# 1       2.079442
# 2       2.302585
# 3       2.397895
# 4       2.079442
#           ...
# 4172    2.484907
# 4173    2.397895
# 4174    2.302585
# 4175    2.397895
# 4176    2.564949
# Name: Rings, Length: 4177, dtype: float64

# %%
X.shape
# Out:
# (4177, 7)

# %%
Y.shape
# Out:
# (4177,)

# %%
Y = Y.values.reshape(-1,1)

# %%
Y
# Out:
# array([[2.77258872],
#        [2.07944154],
#        [2.30258509],
#        ...,
#        [2.30258509],
#        [2.39789527],
#        [2.56494936]])

# %%
Y.shape
# Out:
# (4177, 1)

# %% [markdown]
# #### Applying Linear Regression

# %%
from sklearn.model_selection import train_test_split
train_X,test_X,train_Y,test_Y=train_test_split(X,Y,test_size=.33,random_state=39)

# %%
train_X.shape
# Out:
# (2798, 7)

# %%
train_Y.shape
# Out:
# (2798, 1)

# %%
test_X.shape
# Out:
# (1379, 7)

# %%
test_Y.shape
# Out:
# (1379, 1)

# %%
lg = LinearRegression()

# %%
lg.fit(train_X,train_Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lg.coef_
# Out:
# array([[ 0.53702417,  1.44128145,  2.67510389,  0.28772271, -2.02706646,
#         -0.55912085,  1.15763035]])

# %%
lg.intercept_
# Out:
# array([1.34528761])

# %%
lg.score(train_X,train_Y)
# Out:
# 0.6007143033923903

# %%
#predict the value
pred=lg.predict(test_X)
print("Predicted result price:",pred)
print("actual price",test_Y)
# Out:
# Predicted result price: [[2.71093697]
#  [2.17755175]
#  [2.47974441]
#  ...
#  [2.35705836]
#  [2.80331309]
#  [2.45113362]]
# actual price [[2.63905733]
#  [2.30258509]
#  [2.30258509]
#  ...
#  [2.39789527]
#  [2.7080502 ]
#  [2.7080502 ]]

# %%
print('error:')

print('Mean absolute error:',mean_absolute_error(test_Y,pred))
print('Mean sqaured error:',mean_squared_error(test_Y,pred))

print('Root mean squared error:',np.sqrt(mean_squared_error(test_Y,pred)))
# Out:
# error:
# Mean absolute error: 0.140284814875327
# Mean sqaured error: 0.03315145106789929
# Root mean squared error: 0.18207539940337708

# %% [markdown]
# #### Boost through GradientBoostRegressor By using Parameters

# %%
from sklearn import ensemble
# Fit regression model
params = {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
modelgbr = ensemble.GradientBoostingRegressor(**params)

modelgbr.fit(train_X, train_Y)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.01, loss='ls', max_depth=4,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=500,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
from sklearn.metrics import mean_squared_error, r2_score
model_score = modelgbr.score(train_X,train_Y)
print("model_Score:",model_score)


y_predictedgbr = modelgbr.predict(test_X)

# The mean squared error
print("Mean squared error: %.2f"% mean_squared_error(test_Y, y_predictedgbr))
# Explained variance score: 1 is perfect prediction
print('R2 Score: %.2f' % r2_score(test_Y, y_predictedgbr))
# Out:
# model_Score: 0.7188172026461964
# Mean squared error: 0.03
# R2 Score: 0.61

# %% [markdown]
# #### Lets Visualize the Goodness of the Prediction

# %%
from sklearn.model_selection import cross_val_predict

fig, ax = plt.subplots()
ax.scatter(test_Y, y_predictedgbr, edgecolors=(0, 0, 0))
ax.plot([test_Y.min(), test_Y.max()], [test_Y.min(), test_Y.max()], 'k--', lw=4)
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Ground Truth vs Predicted")
plt.show()

# %% [markdown]
# ### Linear Regression using Recursion

# %%
from sklearn.model_selection import train_test_split
train_X,test_X,train_Y,test_Y = train_test_split(X,Y,random_state=55,test_size=0.20)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,X,Y):
    max_r_score=0
    for r_state in range(42,100):
        train_X,test_X,train_Y,test_Y=train_test_split(X,Y,test_size=.20,random_state=r_state)
        regr.fit(train_X,train_Y)
        y_pred = regr.predict(test_X)
        r2_scr=r2_score(test_Y,y_pred)
        print("r2 score corresponding to ",r_state,"is",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state,"is",max_r_score)
    return final_r_state

# %%
# Lets use LinearRegression and check the max r2 score corresponding to different state
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()
r_state = maxr2_score(lreg,X,Y)
# Out:
# r2 score corresponding to  42 is 0.5976886350552193
# r2 score corresponding to  43 is 0.617016748399352
# r2 score corresponding to  44 is 0.5925600787329888
# r2 score corresponding to  45 is 0.5700658126542372
# r2 score corresponding to  46 is 0.5983727145384546
# r2 score corresponding to  47 is 0.5021850216390957
# r2 score corresponding to  48 is 0.5979230815711438
# r2 score corresponding to  49 is 0.5687226409441204
# r2 score corresponding to  50 is 0.5555280421990438
# r2 score corresponding to  51 is 0.5764741880809245
# r2 score corresponding to  52 is 0.5941353188995022
# r2 score corresponding to  53 is 0.607530055529716
# r2 score corresponding to  54 is 0.5539611670609912
# r2 score corresponding to  55 is 0.5788644749512665
# r2 score corresponding to  56 is 0.554415220227621
# r2 score corresponding to  57 is 0.5536109272389669
# r2 score corresponding to  58 is 0.5946049707526191
# r2 score corresponding to  59 is 0.5738662559219516
# r2 score corresponding to  60 is 0.5612867349492441
# r2 score corresponding to  61 is 0.5612740491569552
# r2 score corresponding to  62 is 0.5961655322028174
# r2 score corresponding to  63 is 0.5449908213785242
# r2 score corresponding to  64 is 0.5917912597358772
# r2 score corresponding to  65 is 0.5334972421379434
# r2 score corresponding to  66 is 0.529678126872501
# r2 score corresponding to  67 is 0.5781681502044659
# r2 score corresponding to  68 is 0.5561334753282451
# r2 score corresponding to  69 is 0.598760968690739
# r2 score corresponding to  70 is 0.563502061140364
# r2 score corresponding to  71 is 0.5919661921305495
# r2 score corresponding to  72 is 0.5703287061200201
# r2 score corresponding to  73 is 0.5638616835854028
# r2 score corresponding to  74 is 0.5833106151465464
# r2 score corresponding to  75 is 0.5635080002261407
# r2 score corresponding to  76 is 0.5982220097788431
# r2 score corresponding to  77 is 0.5953774870415016
# r2 score corresponding to  78 is 0.5699412959546567
# r2 score corresponding to  79 is 0.5593997332541083
# r2 score corresponding to  80 is 0.5837384348341119
# r2 score corresponding to  81 is 0.6214658109207959
# r2 score corresponding to  82 is 0.6025778713113881
# r2 score corresponding to  83 is 0.5735181480129442
# r2 score corresponding to  84 is 0.5444844339559198
# r2 score corresponding to  85 is 0.6005073089282085
# r2 score corresponding to  86 is 0.5437343209484937
# r2 score corresponding to  87 is 0.5810819928709947
# r2 score corresponding to  88 is 0.6178851600837931
# r2 score corresponding to  89 is 0.6225267646117567
# r2 score corresponding to  90 is 0.5709135373186043
# r2 score corresponding to  91 is 0.5751182864329525
# r2 score corresponding to  92 is 0.5192934711858037
# r2 score corresponding to  93 is 0.6003089662696518
# r2 score corresponding to  94 is 0.6038908866735879
# r2 score corresponding to  95 is 0.6115694861751001
# r2 score corresponding to  96 is 0.5871389875730528
# r2 score corresponding to  97 is 0.5893590820930228
# r2 score corresponding to  98 is 0.5395924301287138
# r2 score corresponding to  99 is 0.5460463998184726
# max r2 score corresponding to  89 is 0.6225267646117567

# %% [markdown]
# ### KNN Model

# %%
from sklearn.neighbors import KNeighborsRegressor
knr1 = KNeighborsRegressor()
knr1.fit(train_X,train_Y)
knr1.score(train_X,train_Y)
predicted=knr1.predict(test_X)
print("Mean squared error of linear svc: %.2f"% mean_squared_error(test_Y,predicted))
print('R2 Score of linear svc: %.2f' % r2_score(test_Y, predicted))
# Out:
# Mean squared error of linear svc: 0.03
# R2 Score of linear svc: 0.58

# %% [markdown]
# ### Lets use grid_search to find optimal value of n_neighbors for KNN Model

# %%
#Lets use the Grid Search to Find the Optimal Value of n_neighbors in Knn Model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import NearestNeighbors
neighbors={"n_neighbors":range(1,30)}
knr = KNeighborsRegressor()
gknr = GridSearchCV(knr,neighbors,cv=10)
gknr.fit(X,Y)
gknr.best_params_
# Out:
# {'n_neighbors': 19}

# %%
#Lets Use Knn Regression and Check max r2 score corresponding to different random states
knr = KNeighborsRegressor(n_neighbors=19)
r_state = maxr2_score(knr,X,Y)
# Out:
# r2 score corresponding to  42 is 0.6418420907593807
# r2 score corresponding to  43 is 0.6542719595387725
# r2 score corresponding to  44 is 0.6260068174464993
# r2 score corresponding to  45 is 0.6156400673028983
# r2 score corresponding to  46 is 0.644372520758586
# r2 score corresponding to  47 is 0.5949196680379811
# r2 score corresponding to  48 is 0.6405535753677405
# r2 score corresponding to  49 is 0.6190904383255396
# r2 score corresponding to  50 is 0.6252235146167211
# r2 score corresponding to  51 is 0.6418278226437542
# r2 score corresponding to  52 is 0.6326281133082986
# r2 score corresponding to  53 is 0.6348863908905589
# r2 score corresponding to  54 is 0.6043040665838983
# r2 score corresponding to  55 is 0.6277228544084057
# r2 score corresponding to  56 is 0.6244353344555738
# r2 score corresponding to  57 is 0.6233263238585405
# r2 score corresponding to  58 is 0.6456067926989425
# r2 score corresponding to  59 is 0.6410883619091612
# r2 score corresponding to  60 is 0.6281224833879953
# r2 score corresponding to  61 is 0.6262931941321057
# r2 score corresponding to  62 is 0.6356853939787189
# r2 score corresponding to  63 is 0.6268744135171896
# r2 score corresponding to  64 is 0.6166065504475582
# r2 score corresponding to  65 is 0.5944445623930672
# r2 score corresponding to  66 is 0.6227355610942102
# r2 score corresponding to  67 is 0.626156821520893
# r2 score corresponding to  68 is 0.6050867793848291
# r2 score corresponding to  69 is 0.6269532709142318
# r2 score corresponding to  70 is 0.6155478578713125
# r2 score corresponding to  71 is 0.6106418484789583
# r2 score corresponding to  72 is 0.6075379435559208
# r2 score corresponding to  73 is 0.6153362126165359
# r2 score corresponding to  74 is 0.6040125215111628
# r2 score corresponding to  75 is 0.6088794099777523
# r2 score corresponding to  76 is 0.6365769350429272
# r2 score corresponding to  77 is 0.6215981936574068
# r2 score corresponding to  78 is 0.631594595279847
# r2 score corresponding to  79 is 0.62067509071092
# r2 score corresponding to  80 is 0.6160158219049551
# r2 score corresponding to  81 is 0.6418500100364706
# r2 score corresponding to  82 is 0.6504210117149292
# r2 score corresponding to  83 is 0.6168221301579047
# r2 score corresponding to  84 is 0.5921201510643325
# r2 score corresponding to  85 is 0.6365508529289341
# r2 score corresponding to  86 is 0.6139562222413426
# r2 score corresponding to  87 is 0.6050302455432708
# r2 score corresponding to  88 is 0.6584831379514
# r2 score corresponding to  89 is 0.6655058918232735
# r2 score corresponding to  90 is 0.6031382234454233
# r2 score corresponding to  91 is 0.6328382659492557
# r2 score corresponding to  92 is 0.5825884467765243
# r2 score corresponding to  93 is 0.6237088151929107
# r2 score corresponding to  94 is 0.6311749940794225
# r2 score corresponding to  95 is 0.6373339644031855
# r2 score corresponding to  96 is 0.6186256346124435
# r2 score corresponding to  97 is 0.639967555190416
# r2 score corresponding to  98 is 0.6101809043377401
# r2 score corresponding to  99 is 0.6255681315269817
# max r2 score corresponding to  89 is 0.6655058918232735

# %%
#Lets check the mean r2 score of both linear regression model and knn regression 
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Linear Regression:",cross_val_score(lreg,X,Y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 scorefor Linear Regression:",cross_val_score(lreg,X,Y,cv=5,scoring="r2").std())
print()
print("Mean r2 score for KNN Regression: ",cross_val_score(knr,X,Y,cv=5,scoring="r2").mean())
print("Stadard deviation in r2 score for KNN Regression:",cross_val_score(knr,X,Y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Linear Regression: 0.506164076754331
# Standard deviation in r2 scorefor Linear Regression: 0.06361644527146502
#
# Mean r2 score for KNN Regression:  0.5689918352039645
# Stadard deviation in r2 score for KNN Regression: 0.05443102952911815

# %% [markdown]
# ### Boosting Linear Regression

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_reg1=AdaBoostRegressor()
add_reg1=AdaBoostRegressor(base_estimator=lreg,learning_rate=0.1,n_estimators=10)
print("Mean r2 score for ada boosting Regression: ",cross_val_score(ada_reg1,X,Y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for ada boosting Regression: ",cross_val_score(ada_reg1,X,Y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for ada boosting Regression:  0.3763564427573157
# Standard deviation in r2 score for ada boosting Regression:  0.21851215743502334

# %% [markdown]
# ### Boosting KNN model

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_reg2=AdaBoostRegressor()
add_reg2=AdaBoostRegressor(base_estimator=knr,learning_rate=0.1,n_estimators=10)
print("Mean r2 score for ada boosting Regression: ",cross_val_score(ada_reg2,X,Y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for ada boosting Regression: ",cross_val_score(ada_reg2,X,Y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for ada boosting Regression:  0.36772713863856826
# Standard deviation in r2 score for ada boosting Regression:  0.2655171777593763

# %% [markdown]
# #### Lets check lasso regression and best value of alpha

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf = GridSearchCV(lsreg,parameters,cv=10)
clf.fit(X,Y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
#Lets use cross val score with Lasso
lasso_grs=Lasso(alpha = 0.001)
print("Mean r2 score for Lasso Regression: ",cross_val_score(lasso_grs,X,Y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Lasso Regression: ",cross_val_score(lasso_grs,X,Y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Lasso Regression:  0.46907451703250774
# Standard deviation in r2 score for Lasso Regression:  0.0775333915204163

# %% [markdown]
# ### Boosting Lasso Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_reg3=AdaBoostRegressor()
add_reg3=AdaBoostRegressor(base_estimator=lasso_grs,learning_rate=0.1,n_estimators=10)
print("Mean r2 score for ada boosting Regression: ",cross_val_score(ada_reg3,X,Y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for ada boosting Regression: ",cross_val_score(ada_reg3,X,Y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for ada boosting Regression:  0.3757785610608879
# Standard deviation in r2 score for ada boosting Regression:  0.24621806786334535

# %% [markdown]
# ### Support Vector Regression

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

svr1 = SVR(kernel = "linear")
svr1.fit(train_X,train_Y)
svr1.score(train_X,train_Y)
y_pred1=svr1.predict(test_X)
print("Mean squared error of linear svc: %.2f"% mean_squared_error(test_Y,y_pred1))
print('R2 Score of linear svc: %.2f' % r2_score(test_Y, y_pred1))


svr2 = SVR(kernel = "poly")
svr2.fit(train_X,train_Y)
svr2.score(train_X,train_Y)
y_pred2=svr2.predict(test_X)
print("Mean squared error of poly svc: %.2f"% mean_squared_error(test_Y,y_pred2))
print('R2 Score of poly svc: %.2f' % r2_score(test_Y, y_pred2))


svr3 = SVR(kernel = "rbf")
svr3.fit(train_X,train_Y)
svr3.score(train_X,train_Y)
y_pred3=svr3.predict(test_X)
print("Mean squared error of rbf svc: %.2f"% mean_squared_error(test_Y,y_pred3))
print('R2 Score of rbf svc: %.2f' % r2_score(test_Y, y_pred3))
# Out:
# Mean squared error of linear svc: 0.03
# R2 Score of linear svc: 0.58
# Mean squared error of poly svc: 0.05
# R2 Score of poly svc: 0.39
# Mean squared error of rbf svc: 0.03
# R2 Score of rbf svc: 0.62

# %% [markdown]
# #### Grid Search CV in Support Vector Regressor

# %%
from sklearn.svm import SVR
import numpy as np
parameters = {'kernel': ('linear', 'rbf','poly'), 'C':[1.5, 10],'gamma': [1e-7, 1e-4],'epsilon':[0.1,0.2,0.5,0.3]}
svr = SVR()
grs = GridSearchCV(svr, parameters,refit = True, verbose = 3)
grs.fit(X,Y)
grs.best_params_
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear ..................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear, score=0.569, total=   0.2s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear, score=0.562, total=   0.2s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear, score=0.550, total=   0.3s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=rbf, score=-0.044, total=   0.4s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=rbf, score=-0.030, total=   0.3s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=rbf, score=-0.019, total=   0.3s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=poly, score=-0.045, total=   0.2s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=poly, score=-0.031, total=   0.2s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=poly, score=-0.020, total=   0.2s
# [CV] C=1.5, epsilon=0.1, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.1, gamma=0.0001, kernel=linear, score=0.569, total=   0.2s
# [CV] C=1.5, epsilon=0.1, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.1, gamma=0.0001, kernel=linear, score=0.562, total=   0.2s
# [CV] C=1.5, epsilon=0.1, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.1, gamma=0.0001, kernel=linear, score=0.550, total=   0.2s
# [CV] C=1.5, epsilon=0.1, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.1, gamma=0.0001, kernel=rbf, score=0.193, total=   0.3s
# [CV] C=1.5, epsilon=0.1, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.1, gamma=0.0001, kernel=rbf, score=0.259, total=   0.3s
# [CV] C=1.5, epsilon=0.1, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.1, gamma=0.0001, kernel=rbf, score=0.259, total=   0.3s
# [CV] C=1.5, epsilon=0.1, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.1, gamma=0.0001, kernel=poly, score=-0.045, total=   0.2s
# [CV] C=1.5, epsilon=0.1, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.1, gamma=0.0001, kernel=poly, score=-0.031, total=   0.2s
# [CV] C=1.5, epsilon=0.1, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.1, gamma=0.0001, kernel=poly, score=-0.020, total=   0.2s
# [CV] C=1.5, epsilon=0.2, gamma=1e-07, kernel=linear ..................
# [CV]  C=1.5, epsilon=0.2, gamma=1e-07, kernel=linear, score=0.596, total=   0.1s
# [CV] C=1.5, epsilon=0.2, gamma=1e-07, kernel=linear ..................
# [CV]  C=1.5, epsilon=0.2, gamma=1e-07, kernel=linear, score=0.547, total=   0.1s
# [CV] C=1.5, epsilon=0.2, gamma=1e-07, kernel=linear ..................
# [CV]  C=1.5, epsilon=0.2, gamma=1e-07, kernel=linear, score=0.534, total=   0.1s
# [CV] C=1.5, epsilon=0.2, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.2, gamma=1e-07, kernel=rbf, score=0.000, total=   0.2s
# [CV] C=1.5, epsilon=0.2, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.2, gamma=1e-07, kernel=rbf, score=-0.010, total=   0.2s
# [CV] C=1.5, epsilon=0.2, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.2, gamma=1e-07, kernel=rbf, score=-0.004, total=   0.2s
# [CV] C=1.5, epsilon=0.2, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.2, gamma=1e-07, kernel=poly, score=-0.000, total=   0.1s
# [CV] C=1.5, epsilon=0.2, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.2, gamma=1e-07, kernel=poly, score=-0.010, total=   0.1s
# [CV] C=1.5, epsilon=0.2, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.2, gamma=1e-07, kernel=poly, score=-0.004, total=   0.1s
# [CV] C=1.5, epsilon=0.2, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.2, gamma=0.0001, kernel=linear, score=0.596, total=   0.1s
# [CV] C=1.5, epsilon=0.2, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.2, gamma=0.0001, kernel=linear, score=0.547, total=   0.1s
# [CV] C=1.5, epsilon=0.2, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.2, gamma=0.0001, kernel=linear, score=0.534, total=   0.2s
# [CV] C=1.5, epsilon=0.2, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.2, gamma=0.0001, kernel=rbf, score=0.173, total=   0.2s
# [CV] C=1.5, epsilon=0.2, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.2, gamma=0.0001, kernel=rbf, score=0.234, total=   0.2s
# [CV] C=1.5, epsilon=0.2, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.2, gamma=0.0001, kernel=rbf, score=0.233, total=   0.2s
# [CV] C=1.5, epsilon=0.2, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.2, gamma=0.0001, kernel=poly, score=-0.000, total=   0.1s
# [CV] C=1.5, epsilon=0.2, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.2, gamma=0.0001, kernel=poly, score=-0.010, total=   0.1s
# [CV] C=1.5, epsilon=0.2, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.2, gamma=0.0001, kernel=poly, score=-0.004, total=   0.2s
# [CV] C=1.5, epsilon=0.5, gamma=1e-07, kernel=linear ..................
# [CV]  C=1.5, epsilon=0.5, gamma=1e-07, kernel=linear, score=0.507, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=1e-07, kernel=linear ..................
# [CV]  C=1.5, epsilon=0.5, gamma=1e-07, kernel=linear, score=0.202, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=1e-07, kernel=linear ..................
# [CV]  C=1.5, epsilon=0.5, gamma=1e-07, kernel=linear, score=0.213, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.5, gamma=1e-07, kernel=rbf, score=-0.010, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.5, gamma=1e-07, kernel=rbf, score=-0.038, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.5, gamma=1e-07, kernel=rbf, score=-0.026, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.5, gamma=1e-07, kernel=poly, score=-0.011, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.5, gamma=1e-07, kernel=poly, score=-0.038, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.5, gamma=1e-07, kernel=poly, score=-0.027, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.5, gamma=0.0001, kernel=linear, score=0.507, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.5, gamma=0.0001, kernel=linear, score=0.202, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.5, gamma=0.0001, kernel=linear, score=0.213, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.5, gamma=0.0001, kernel=rbf, score=0.062, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.5, gamma=0.0001, kernel=rbf, score=0.116, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.5, gamma=0.0001, kernel=rbf, score=0.113, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.5, gamma=0.0001, kernel=poly, score=-0.011, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.5, gamma=0.0001, kernel=poly, score=-0.038, total=   0.0s
# [CV] C=1.5, epsilon=0.5, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.5, gamma=0.0001, kernel=poly, score=-0.027, total=   0.0s
# [CV] C=1.5, epsilon=0.3, gamma=1e-07, kernel=linear ..................
# [CV]  C=1.5, epsilon=0.3, gamma=1e-07, kernel=linear, score=0.603, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=1e-07, kernel=linear ..................
# [CV]  C=1.5, epsilon=0.3, gamma=1e-07, kernel=linear, score=0.488, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=1e-07, kernel=linear ..................
# [CV]  C=1.5, epsilon=0.3, gamma=1e-07, kernel=linear, score=0.489, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.3, gamma=1e-07, kernel=rbf, score=-0.007, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.3, gamma=1e-07, kernel=rbf, score=-0.024, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.3, gamma=1e-07, kernel=rbf, score=-0.014, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.3, gamma=1e-07, kernel=poly, score=-0.007, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.3, gamma=1e-07, kernel=poly, score=-0.024, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=1e-07, kernel=poly ....................
# [CV]  C=1.5, epsilon=0.3, gamma=1e-07, kernel=poly, score=-0.015, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.3, gamma=0.0001, kernel=linear, score=0.603, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.3, gamma=0.0001, kernel=linear, score=0.488, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=0.0001, kernel=linear .................
# [CV]  C=1.5, epsilon=0.3, gamma=0.0001, kernel=linear, score=0.489, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.3, gamma=0.0001, kernel=rbf, score=0.140, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.3, gamma=0.0001, kernel=rbf, score=0.176, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=0.0001, kernel=rbf ....................
# [CV]  C=1.5, epsilon=0.3, gamma=0.0001, kernel=rbf, score=0.178, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.3, gamma=0.0001, kernel=poly, score=-0.007, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.3, gamma=0.0001, kernel=poly, score=-0.024, total=   0.1s
# [CV] C=1.5, epsilon=0.3, gamma=0.0001, kernel=poly ...................
# [CV]  C=1.5, epsilon=0.3, gamma=0.0001, kernel=poly, score=-0.015, total=   0.1s
# [CV] C=10, epsilon=0.1, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.1, gamma=1e-07, kernel=linear, score=0.577, total=   0.4s
# [CV] C=10, epsilon=0.1, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.1, gamma=1e-07, kernel=linear, score=0.549, total=   0.4s
# [CV] C=10, epsilon=0.1, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.1, gamma=1e-07, kernel=linear, score=0.550, total=   0.3s
# [CV] C=10, epsilon=0.1, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.1, gamma=1e-07, kernel=rbf, score=-0.041, total=   0.3s
# [CV] C=10, epsilon=0.1, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.1, gamma=1e-07, kernel=rbf, score=-0.027, total=   0.3s
# [CV] C=10, epsilon=0.1, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.1, gamma=1e-07, kernel=rbf, score=-0.013, total=   0.3s
# [CV] C=10, epsilon=0.1, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.1, gamma=1e-07, kernel=poly, score=-0.045, total=   0.2s
# [CV] C=10, epsilon=0.1, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.1, gamma=1e-07, kernel=poly, score=-0.031, total=   0.2s
# [CV] C=10, epsilon=0.1, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.1, gamma=1e-07, kernel=poly, score=-0.020, total=   0.2s
# [CV] C=10, epsilon=0.1, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.1, gamma=0.0001, kernel=linear, score=0.577, total=   0.4s
# [CV] C=10, epsilon=0.1, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.1, gamma=0.0001, kernel=linear, score=0.549, total=   0.4s
# [CV] C=10, epsilon=0.1, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.1, gamma=0.0001, kernel=linear, score=0.550, total=   0.3s
# [CV] C=10, epsilon=0.1, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.1, gamma=0.0001, kernel=rbf, score=0.294, total=   0.3s
# [CV] C=10, epsilon=0.1, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.1, gamma=0.0001, kernel=rbf, score=0.388, total=   0.3s
# [CV] C=10, epsilon=0.1, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.1, gamma=0.0001, kernel=rbf, score=0.372, total=   0.3s
# [CV] C=10, epsilon=0.1, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.1, gamma=0.0001, kernel=poly, score=-0.045, total=   0.2s
# [CV] C=10, epsilon=0.1, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.1, gamma=0.0001, kernel=poly, score=-0.031, total=   0.2s
# [CV] C=10, epsilon=0.1, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.1, gamma=0.0001, kernel=poly, score=-0.020, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.2, gamma=1e-07, kernel=linear, score=0.602, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.2, gamma=1e-07, kernel=linear, score=0.534, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.2, gamma=1e-07, kernel=linear, score=0.536, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.2, gamma=1e-07, kernel=rbf, score=0.002, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.2, gamma=1e-07, kernel=rbf, score=-0.008, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.2, gamma=1e-07, kernel=rbf, score=-0.001, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.2, gamma=1e-07, kernel=poly, score=-0.000, total=   0.1s
# [CV] C=10, epsilon=0.2, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.2, gamma=1e-07, kernel=poly, score=-0.010, total=   0.1s
# [CV] C=10, epsilon=0.2, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.2, gamma=1e-07, kernel=poly, score=-0.004, total=   0.1s
# [CV] C=10, epsilon=0.2, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.2, gamma=0.0001, kernel=linear, score=0.602, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.2, gamma=0.0001, kernel=linear, score=0.534, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.2, gamma=0.0001, kernel=linear, score=0.536, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.2, gamma=0.0001, kernel=rbf, score=0.330, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.2, gamma=0.0001, kernel=rbf, score=0.366, total=   0.3s
# [CV] C=10, epsilon=0.2, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.2, gamma=0.0001, kernel=rbf, score=0.354, total=   0.2s
# [CV] C=10, epsilon=0.2, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.2, gamma=0.0001, kernel=poly, score=-0.000, total=   0.1s
# [CV] C=10, epsilon=0.2, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.2, gamma=0.0001, kernel=poly, score=-0.010, total=   0.1s
# [CV] C=10, epsilon=0.2, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.2, gamma=0.0001, kernel=poly, score=-0.004, total=   0.1s
# [CV] C=10, epsilon=0.5, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.5, gamma=1e-07, kernel=linear, score=0.587, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.5, gamma=1e-07, kernel=linear, score=0.369, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.5, gamma=1e-07, kernel=linear, score=0.336, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.5, gamma=1e-07, kernel=rbf, score=-0.010, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.5, gamma=1e-07, kernel=rbf, score=-0.037, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.5, gamma=1e-07, kernel=rbf, score=-0.025, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.5, gamma=1e-07, kernel=poly, score=-0.011, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.5, gamma=1e-07, kernel=poly, score=-0.038, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.5, gamma=1e-07, kernel=poly, score=-0.027, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.5, gamma=0.0001, kernel=linear, score=0.587, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.5, gamma=0.0001, kernel=linear, score=0.369, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.5, gamma=0.0001, kernel=linear, score=0.336, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.5, gamma=0.0001, kernel=rbf, score=0.210, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.5, gamma=0.0001, kernel=rbf, score=0.202, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.5, gamma=0.0001, kernel=rbf, score=0.199, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.5, gamma=0.0001, kernel=poly, score=-0.011, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.5, gamma=0.0001, kernel=poly, score=-0.038, total=   0.0s
# [CV] C=10, epsilon=0.5, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.5, gamma=0.0001, kernel=poly, score=-0.027, total=   0.0s
# [CV] C=10, epsilon=0.3, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.3, gamma=1e-07, kernel=linear, score=0.615, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.3, gamma=1e-07, kernel=linear, score=0.481, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=1e-07, kernel=linear ...................
# [CV]  C=10, epsilon=0.3, gamma=1e-07, kernel=linear, score=0.495, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.3, gamma=1e-07, kernel=rbf, score=-0.006, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.3, gamma=1e-07, kernel=rbf, score=-0.023, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=1e-07, kernel=rbf ......................
# [CV]  C=10, epsilon=0.3, gamma=1e-07, kernel=rbf, score=-0.013, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.3, gamma=1e-07, kernel=poly, score=-0.007, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.3, gamma=1e-07, kernel=poly, score=-0.024, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=1e-07, kernel=poly .....................
# [CV]  C=10, epsilon=0.3, gamma=1e-07, kernel=poly, score=-0.015, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.3, gamma=0.0001, kernel=linear, score=0.615, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.3, gamma=0.0001, kernel=linear, score=0.481, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=0.0001, kernel=linear ..................
# [CV]  C=10, epsilon=0.3, gamma=0.0001, kernel=linear, score=0.495, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.3, gamma=0.0001, kernel=rbf, score=0.326, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.3, gamma=0.0001, kernel=rbf, score=0.308, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=0.0001, kernel=rbf .....................
# [CV]  C=10, epsilon=0.3, gamma=0.0001, kernel=rbf, score=0.301, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.3, gamma=0.0001, kernel=poly, score=-0.007, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.3, gamma=0.0001, kernel=poly, score=-0.024, total=   0.1s
# [CV] C=10, epsilon=0.3, gamma=0.0001, kernel=poly ....................
# [CV]  C=10, epsilon=0.3, gamma=0.0001, kernel=poly, score=-0.015, total=   0.1s
# [Parallel(n_jobs=1)]: Done 144 out of 144 | elapsed:   20.1s finished
# {'C': 1.5, 'epsilon': 0.1, 'gamma': 1e-07, 'kernel': 'linear'}

# %%
svr_grs=SVR(C=1.5, epsilon=0.1, gamma=1e-07, kernel='linear')
print("Mean r2 score for ada boosting Regression: ",cross_val_score(svr_grs,X,Y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for ada boosting Regression: ",cross_val_score(svr_grs,X,Y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for ada boosting Regression:  0.5134759349180917
# Standard deviation in r2 score for ada boosting Regression:  0.056910695581609785

# %% [markdown]
# ### Boosting Support Vector Machine

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ada_reg4=AdaBoostRegressor()
add_reg4=AdaBoostRegressor(base_estimator=svr_grs,learning_rate=0.1,n_estimators=10)
print("Mean r2 score for ada boosting Regression: ",cross_val_score(ada_reg4,X,Y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for ada boosting Regression: ",cross_val_score(ada_reg4,X,Y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for ada boosting Regression:  0.3666243178068377
# Standard deviation in r2 score for ada boosting Regression:  0.2540752463344181

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
  

dtregressor = DecisionTreeRegressor(random_state = 0)  
  
 
dtregressor.fit(X, Y) 

dtregressor.score(train_X,train_Y)
y_pred4=dtregressor.predict(test_X)
print("Mean squared error of Decision Tree Regressor: %.2f"% mean_squared_error(test_Y,y_pred4))
print('R2 Score : %.2f' % r2_score(test_Y, y_pred4))
# Out:
# Mean squared error of Decision Tree Regressor: 0.00
# R2 Score : 1.00

# %% [markdown]
# ### Decision Tree Regressor Using GridSearchCV

# %%
dtm = DecisionTreeRegressor(max_depth=4,
                           min_samples_split=5,
                           max_leaf_nodes=10)

dtm.fit(X,Y)
print("R-Squared on train dataset={}".format(dtm.score(test_X,test_Y)))

dtm.fit(test_X,test_Y)   
print("R-Squaredon test dataset={}".format(dtm.score(test_X,test_Y)))
# Out:
# R-Squared on train dataset=0.5523033537385504
# R-Squaredon test dataset=0.6010164485040345

# %%
param_grid = {"criterion": ["mse", "mae"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100],
              }


grid_cv_dtm = GridSearchCV(dtm, param_grid, cv=5)

grid_cv_dtm.fit(X,Y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=4,
#                                              max_features=None,
#                                              max_leaf_nodes=10,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=5,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=None,
#                                              splitter='best'),
#              iid='warn', n_jobs=None,
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [2, 6, 8],
#                          'max_leaf_nodes': [5, 20, 100],
#                          'min_samples_leaf': [20, 40, 100],
#                          'min_samples_split': [10, 20, 40]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print("R-Squared::{}".format(grid_cv_dtm.best_score_))
print("Best Hyperparameters::\n{}".format(grid_cv_dtm.best_params_))
# Out:
# R-Squared::0.5180101695421526
# Best Hyperparameters::
# {'criterion': 'mse', 'max_depth': 8, 'max_leaf_nodes': 100, 'min_samples_leaf': 40, 'min_samples_split': 10}

# %% [markdown]
# ### Boosting Decision Tree

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ada_reg5=AdaBoostRegressor()
add_reg5=AdaBoostRegressor(base_estimator=dtm,learning_rate=0.1,n_estimators=10)
print("Mean r2 score for ada boosting Regression: ",cross_val_score(add_reg5,X,Y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for ada boosting Regression: ",cross_val_score(add_reg5,X,Y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for ada boosting Regression:  0.5001593292905898
# Standard deviation in r2 score for ada boosting Regression:  0.0871964944937613

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfregressor = RandomForestRegressor(n_estimators=5)
rfregressor.fit(train_X, train_Y)
y_pred5 = rfregressor.predict(test_X)
print("Mean squared error of poly svc: %.2f"% mean_squared_error(test_Y,y_pred5))
print('R2 Score : %.2f' % r2_score(test_Y, y_pred5))
# Out:
# Mean squared error of poly svc: 0.04
# R2 Score : 0.52

# %% [markdown]
# #### Random Forest Regressor with GridSearchCV

# %%
rf_gs = RandomForestRegressor(n_estimators=100)

# %%
n_features = X.shape[1]

# %%
from sklearn.model_selection import RandomizedSearchCV
grid = RandomizedSearchCV(rf_gs, n_iter=20, 
            param_distributions=dict(
                                          max_depth=np.arange(5,20+1), 
                                          max_features=np.arange(1, n_features+1)
                                    )
         )
grid.fit(X, Y)
print(grid.best_params_)
# Out:
# {'max_features': 5, 'max_depth': 8}

# %%
rf_gss = RandomForestRegressor(max_features = 3, max_depth = 9)
print("Mean r2 score for ada boosting Regression: ",cross_val_score(rf_gss,X,Y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for ada boosting Regression: ",cross_val_score(rf_gss,X,Y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for ada boosting Regression:  0.552837205626279
# Standard deviation in r2 score for ada boosting Regression:  0.052952259069213053

# %% [markdown]
# #### Boosting RandomForestRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_reg6=AdaBoostRegressor()
add_reg6=AdaBoostRegressor(base_estimator=rfregressor,learning_rate=0.1,n_estimators=10)
print("Mean r2 score for ada boosting Regression: ",cross_val_score(add_reg6,X,Y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for ada boosting Regression: ",cross_val_score(add_reg6,X,Y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for ada boosting Regression:  0.5596650356188174
# Standard deviation in r2 score for ada boosting Regression:  0.04569427605912785

# %% [markdown]
# #### NOTE::Among all models,dtregressor gives the Highest r2 score(1) and mean squared error is zero so we are going to save this model

# %%
#Lets save the above model
from sklearn.externals import joblib

#Save the model as pickle in a file
joblib.dump(dtregressor,'Abalone.pkl')
# Out:
# ['Abalone.pkl']
